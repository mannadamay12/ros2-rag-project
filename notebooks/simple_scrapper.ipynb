# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import os

# Base URL of the site
base_url = "https://docs.ros.org/"

# Set to store visited URLs to prevent duplication
visited_urls = set()

# Directory to save scraped data
output_dir = "scraped_docs"
os.makedirs(output_dir, exist_ok=True)

def save_to_file(url, content):
    """
    Save scraped content to a text file.
    :param url: The URL of the page
    :param content: The content to write to the file
    """
    # Generate a valid filename from the URL
    parsed_url = urlparse(url)
    filename = f"{parsed_url.netloc}_{parsed_url.path.replace('/', '_').strip('_')}.txt"
    file_path = os.path.join(output_dir, filename)

    # Write content to the file
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)
    print(f"Saved content to {file_path}")

def scrape_page_dfs(url, depth=1, max_depth=3):
    """
    Perform DFS scraping of the given URL.
    :param url: URL to scrape
    :param depth: Current depth level
    :param max_depth: Maximum depth to recurse into links
    """
    if depth > max_depth or url in visited_urls:
        return

    # Add to visited URLs
    visited_urls.add(url)

    try:
        # Fetch the page content
        response = requests.get(url, timeout=10)
        if response.status_code != 200:
            print(f"Failed to access {url} (Status code: {response.status_code})")
            return

        print(f"\nScraping {url} (Depth: {depth})")
        soup = BeautifulSoup(response.content, "html.parser")

        # Prepare content for saving
        content = f"URL: {url}\n"
        title = soup.title.string if soup.title else "No title"
        content += f"Page Title: {title}\n\n"

        # Extract and add headings
        headings = soup.find_all(['h1', 'h2'])
        content += "Headings:\n"
        for heading in headings:
            content += f"- {heading.text.strip()}\n"

        # Extract and add paragraphs
        paragraphs = soup.find_all('p')
        content += "\nParagraphs:\n"
        for paragraph in paragraphs[:3]:  # Limit to first 3 for brevity
            content += f"- {paragraph.text.strip()}\n"

        # Save content to a file
        save_to_file(url, content)

        # Extract internal links and perform DFS
        print("\nFollowing links:")
        links = soup.find_all('a', href=True)
        for link in links:
            href = link['href']
            # Convert relative URLs to absolute URLs
            full_url = urljoin(url, href)
            # Ensure the link is within the docs.ros.org domain and not visited
            if base_url in full_url and full_url not in visited_urls:
                print(f"Found link: {full_url}")
                scrape_page_dfs(full_url, depth + 1, max_depth)

    except Exception as e:
        print(f"Error scraping {url}: {e}")

# Start DFS scraping from the base URL
scrape_page_dfs(base_url, depth=1, max_depth=3)
# Out:
# Scraping https://docs.ros.org/ (Depth: 1)
# Saved content to scraped_docs/docs.ros.org_.txt
#
# Following links:
# Found link: https://docs.ros.org/en/humble
#
# Scraping https://docs.ros.org/en/humble (Depth: 2)
# Saved content to scraped_docs/docs.ros.org_en_humble.txt
#
# Following links:
# Found link: https://docs.ros.org/en/Installation.html
# Failed to access https://docs.ros.org/en/Installation.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Ubuntu-Install-Debs.html
# Failed to access https://docs.ros.org/en/Installation/Ubuntu-Install-Debs.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Windows-Install-Binary.html
# Failed to access https://docs.ros.org/en/Installation/Windows-Install-Binary.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/RHEL-Install-RPMs.html
# Failed to access https://docs.ros.org/en/Installation/RHEL-Install-RPMs.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/Ubuntu-Development-Setup.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/Ubuntu-Development-Setup.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/Ubuntu-Install-Binary.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/Ubuntu-Install-Binary.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/Windows-Development-Setup.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/Windows-Development-Setup.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/RHEL-Development-Setup.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/RHEL-Development-Setup.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/RHEL-Install-Binary.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/RHEL-Install-Binary.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/macOS-Development-Setup.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/macOS-Development-Setup.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/Fedora-Development-Setup.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/Fedora-Development-Setup.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Alternatives/Latest-Development-Setup.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/Latest-Development-Setup.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Maintaining-a-Source-Checkout.html
# Failed to access https://docs.ros.org/en/Installation/Maintaining-a-Source-Checkout.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/Testing.html
# Failed to access https://docs.ros.org/en/Installation/Testing.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/DDS-Implementations.html
# Failed to access https://docs.ros.org/en/Installation/DDS-Implementations.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/DDS-Implementations/Install-Connext-Security-Plugins.html
# Failed to access https://docs.ros.org/en/Installation/DDS-Implementations/Install-Connext-Security-Plugins.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/DDS-Implementations/Install-Connext-University-Eval.html
# Failed to access https://docs.ros.org/en/Installation/DDS-Implementations/Install-Connext-University-Eval.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/DDS-Implementations/Working-with-Eclipse-CycloneDDS.html
# Failed to access https://docs.ros.org/en/Installation/DDS-Implementations/Working-with-Eclipse-CycloneDDS.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/DDS-Implementations/Working-with-GurumNetworks-GurumDDS.html
# Failed to access https://docs.ros.org/en/Installation/DDS-Implementations/Working-with-GurumNetworks-GurumDDS.html (Status code: 404)
# Found link: https://docs.ros.org/en/Installation/DDS-Implementations/Working-with-eProsima-Fast-DDS.html
# Failed to access https://docs.ros.org/en/Installation/DDS-Implementations/Working-with-eProsima-Fast-DDS.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases.html
# Failed to access https://docs.ros.org/en/Releases.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Jazzy-Jalisco.html
# Failed to access https://docs.ros.org/en/Releases/Release-Jazzy-Jalisco.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Jazzy-Jalisco-Complete-Changelog.html
# Failed to access https://docs.ros.org/en/Releases/Jazzy-Jalisco-Complete-Changelog.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Iron-Irwini.html
# Failed to access https://docs.ros.org/en/Releases/Release-Iron-Irwini.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Iron-Irwini-Complete-Changelog.html
# Failed to access https://docs.ros.org/en/Releases/Iron-Irwini-Complete-Changelog.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Humble-Hawksbill.html
# Failed to access https://docs.ros.org/en/Releases/Release-Humble-Hawksbill.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Humble-Hawksbill-Complete-Changelog.html
# Failed to access https://docs.ros.org/en/Releases/Humble-Hawksbill-Complete-Changelog.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Rolling-Ridley.html
# Failed to access https://docs.ros.org/en/Releases/Release-Rolling-Ridley.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Development.html
# Failed to access https://docs.ros.org/en/Releases/Development.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Kilted-Kaiju.html
# Failed to access https://docs.ros.org/en/Releases/Release-Kilted-Kaiju.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/End-of-Life.html
# Failed to access https://docs.ros.org/en/Releases/End-of-Life.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Galactic-Geochelone.html
# Failed to access https://docs.ros.org/en/Releases/Release-Galactic-Geochelone.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Galactic-Geochelone-Complete-Changelog.html
# Failed to access https://docs.ros.org/en/Releases/Galactic-Geochelone-Complete-Changelog.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Foxy-Fitzroy.html
# Failed to access https://docs.ros.org/en/Releases/Release-Foxy-Fitzroy.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Eloquent-Elusor.html
# Failed to access https://docs.ros.org/en/Releases/Release-Eloquent-Elusor.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Dashing-Diademata.html
# Failed to access https://docs.ros.org/en/Releases/Release-Dashing-Diademata.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Crystal-Clemmys.html
# Failed to access https://docs.ros.org/en/Releases/Release-Crystal-Clemmys.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Bouncy-Bolson.html
# Failed to access https://docs.ros.org/en/Releases/Release-Bouncy-Bolson.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Ardent-Apalone.html
# Failed to access https://docs.ros.org/en/Releases/Release-Ardent-Apalone.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Beta3-Overview.html
# Failed to access https://docs.ros.org/en/Releases/Beta3-Overview.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Beta2-Overview.html
# Failed to access https://docs.ros.org/en/Releases/Beta2-Overview.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Beta1-Overview.html
# Failed to access https://docs.ros.org/en/Releases/Beta1-Overview.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Alpha-Overview.html
# Failed to access https://docs.ros.org/en/Releases/Alpha-Overview.html (Status code: 404)
# Found link: https://docs.ros.org/en/Releases/Release-Process.html
# Failed to access https://docs.ros.org/en/Releases/Release-Process.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials.html
# Failed to access https://docs.ros.org/en/Tutorials.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Configuring-ROS2-Environment.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Configuring-ROS2-Environment.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Introducing-Turtlesim/Introducing-Turtlesim.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Introducing-Turtlesim/Introducing-Turtlesim.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Nodes/Understanding-ROS2-Nodes.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Nodes/Understanding-ROS2-Nodes.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Topics/Understanding-ROS2-Topics.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Topics/Understanding-ROS2-Topics.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Services/Understanding-ROS2-Services.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Services/Understanding-ROS2-Services.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Parameters/Understanding-ROS2-Parameters.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Parameters/Understanding-ROS2-Parameters.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Actions/Understanding-ROS2-Actions.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Actions/Understanding-ROS2-Actions.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Using-Rqt-Console/Using-Rqt-Console.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Using-Rqt-Console/Using-Rqt-Console.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Launching-Multiple-Nodes/Launching-Multiple-Nodes.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Launching-Multiple-Nodes/Launching-Multiple-Nodes.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Recording-And-Playing-Back-Data/Recording-And-Playing-Back-Data.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-CLI-Tools/Recording-And-Playing-Back-Data/Recording-And-Playing-Back-Data.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Colcon-Tutorial.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Colcon-Tutorial.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Creating-A-Workspace/Creating-A-Workspace.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Creating-A-Workspace/Creating-A-Workspace.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Creating-Your-First-ROS2-Package.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Creating-Your-First-ROS2-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Cpp-Publisher-And-Subscriber.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Cpp-Publisher-And-Subscriber.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Publisher-And-Subscriber.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Publisher-And-Subscriber.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Cpp-Service-And-Client.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Cpp-Service-And-Client.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Service-And-Client.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Service-And-Client.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Custom-ROS2-Interfaces.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Custom-ROS2-Interfaces.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Single-Package-Define-And-Use-Interface.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Single-Package-Define-And-Use-Interface.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Using-Parameters-In-A-Class-CPP.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Using-Parameters-In-A-Class-CPP.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Using-Parameters-In-A-Class-Python.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Using-Parameters-In-A-Class-Python.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Getting-Started-With-Ros2doctor.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Getting-Started-With-Ros2doctor.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Pluginlib.html
# Failed to access https://docs.ros.org/en/Tutorials/Beginner-Client-Libraries/Pluginlib.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Rosdep.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Rosdep.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Creating-an-Action.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Creating-an-Action.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Writing-an-Action-Server-Client/Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Writing-an-Action-Server-Client/Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Writing-an-Action-Server-Client/Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Writing-an-Action-Server-Client/Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Writing-a-Composable-Node.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Writing-a-Composable-Node.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Composition.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Composition.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Monitoring-For-Parameter-Changes-CPP.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Monitoring-For-Parameter-Changes-CPP.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Launch/Launch-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Launch/Launch-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Launch/Creating-Launch-Files.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Launch/Creating-Launch-Files.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Launch/Launch-system.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Launch/Launch-system.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Launch/Using-Substitutions.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Launch/Using-Substitutions.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Launch/Using-Event-Handlers.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Launch/Using-Event-Handlers.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Launch/Using-ROS2-Launch-For-Large-Projects.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Launch/Using-ROS2-Launch-For-Large-Projects.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Tf2-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Tf2-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Introduction-To-Tf2.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Introduction-To-Tf2.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Static-Broadcaster-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Static-Broadcaster-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Static-Broadcaster-Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Static-Broadcaster-Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Broadcaster-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Broadcaster-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Broadcaster-Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Broadcaster-Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Listener-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Listener-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Listener-Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Writing-A-Tf2-Listener-Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Adding-A-Frame-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Adding-A-Frame-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Adding-A-Frame-Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Adding-A-Frame-Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Learning-About-Tf2-And-Time-Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Learning-About-Tf2-And-Time-Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Time-Travel-With-Tf2-Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Time-Travel-With-Tf2-Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Debugging-Tf2-Problems.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Debugging-Tf2-Problems.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Quaternion-Fundamentals.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Quaternion-Fundamentals.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Using-Stamped-Datatypes-With-Tf2-Ros-MessageFilter.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Using-Stamped-Datatypes-With-Tf2-Ros-MessageFilter.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Testing/Testing-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Testing/Testing-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Testing/CLI.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Testing/CLI.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Testing/Cpp.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Testing/Cpp.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Testing/Python.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Testing/Python.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Testing/BuildFarmTesting.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Testing/BuildFarmTesting.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/URDF-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/URDF-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/Building-a-Visual-Robot-Model-with-URDF-from-Scratch.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/Building-a-Visual-Robot-Model-with-URDF-from-Scratch.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/Building-a-Movable-Robot-Model-with-URDF.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/Building-a-Movable-Robot-Model-with-URDF.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/Adding-Physical-and-Collision-Properties-to-a-URDF-Model.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/Adding-Physical-and-Collision-Properties-to-a-URDF-Model.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/Using-Xacro-to-Clean-Up-a-URDF-File.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/Using-Xacro-to-Clean-Up-a-URDF-File.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/Using-URDF-with-Robot-State-Publisher.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/Using-URDF-with-Robot-State-Publisher.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/URDF/Exporting-an-URDF-File.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/URDF/Exporting-an-URDF-File.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/RViz/RViz-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/RViz/RViz-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/RViz/RViz-User-Guide/RViz-User-Guide.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/RViz/RViz-User-Guide/RViz-User-Guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/RViz/RViz-Custom-Display/RViz-Custom-Display.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/RViz/RViz-Custom-Display/RViz-Custom-Display.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/RViz/Marker-Display-types/Marker-Display-types.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/RViz/Marker-Display-types/Marker-Display-types.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Topic-Statistics-Tutorial/Topic-Statistics-Tutorial.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Topic-Statistics-Tutorial/Topic-Statistics-Tutorial.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Discovery-Server/Discovery-Server.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Discovery-Server/Discovery-Server.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Allocator-Template-Tutorial.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Allocator-Template-Tutorial.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/FastDDS-Configuration.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/FastDDS-Configuration.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Recording-A-Bag-From-Your-Own-Node-CPP.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Recording-A-Bag-From-Your-Own-Node-CPP.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Recording-A-Bag-From-Your-Own-Node-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Recording-A-Bag-From-Your-Own-Node-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/ROS2-Tracing-Trace-and-Analyze.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/ROS2-Tracing-Trace-and-Analyze.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Reading-From-A-Bag-File-CPP.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Reading-From-A-Bag-File-CPP.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Simulation-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Simulation-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Simulation-Webots.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Simulation-Webots.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Installation-Ubuntu.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Installation-Ubuntu.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Installation-Windows.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Installation-Windows.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Installation-MacOS.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Installation-MacOS.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Setting-Up-Simulation-Webots-Basic.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Setting-Up-Simulation-Webots-Basic.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Setting-Up-Simulation-Webots-Advanced.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Setting-Up-Simulation-Webots-Advanced.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Simulation-Supervisor.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Simulation-Supervisor.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Simulation-Reset-Handler.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots/Simulation-Reset-Handler.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Gazebo/Simulation-Gazebo.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Gazebo/Simulation-Gazebo.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Gazebo/Gazebo.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Gazebo/Gazebo.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/Security-Main.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/Security-Main.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/Introducing-ros2-security.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/Introducing-ros2-security.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/The-Keystore.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/The-Keystore.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/Security-on-Two.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/Security-on-Two.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/Examine-Traffic.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/Examine-Traffic.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/Access-Controls.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/Access-Controls.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Security/Deployment-Guidelines.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Security/Deployment-Guidelines.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Quality-of-Service.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Quality-of-Service.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Managed-Nodes.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Managed-Nodes.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Intra-Process-Communication.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Intra-Process-Communication.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Rosbag-with-ROS1-Bridge.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Rosbag-with-ROS1-Bridge.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Real-Time-Programming.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Real-Time-Programming.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/dummy-robot-demo.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/dummy-robot-demo.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Logging-and-logger-configuration.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Logging-and-logger-configuration.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Demos/Content-Filtering-Subscription.html
# Failed to access https://docs.ros.org/en/Tutorials/Demos/Content-Filtering-Subscription.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Miscellaneous.html
# Failed to access https://docs.ros.org/en/Tutorials/Miscellaneous.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Miscellaneous/Deploying-ROS-2-on-IBM-Cloud.html
# Failed to access https://docs.ros.org/en/Tutorials/Miscellaneous/Deploying-ROS-2-on-IBM-Cloud.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Miscellaneous/Eclipse-Oxygen-with-ROS-2-and-rviz2.html
# Failed to access https://docs.ros.org/en/Tutorials/Miscellaneous/Eclipse-Oxygen-with-ROS-2-and-rviz2.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Miscellaneous/Building-Realtime-rt_preempt-kernel-for-ROS-2.html
# Failed to access https://docs.ros.org/en/Tutorials/Miscellaneous/Building-Realtime-rt_preempt-kernel-for-ROS-2.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Miscellaneous/Building-ROS2-Package-with-eclipse-2021-06.html
# Failed to access https://docs.ros.org/en/Tutorials/Miscellaneous/Building-ROS2-Package-with-eclipse-2021-06.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides.html
# Failed to access https://docs.ros.org/en/How-To-Guides.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Installation-Troubleshooting.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Installation-Troubleshooting.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Developing-a-ROS-2-Package.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Developing-a-ROS-2-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Documenting-a-ROS-2-Package.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Documenting-a-ROS-2-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Ament-CMake-Documentation.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Ament-CMake-Documentation.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Ament-CMake-Python-Documentation.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Ament-CMake-Python-Documentation.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Packages.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Packages.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Package-XML.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Package-XML.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Interfaces.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Interfaces.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-CPP-Package-Example.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-CPP-Package-Example.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-CPP-Packages.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-CPP-Packages.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Python-Package-Example.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Python-Package-Example.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Python-Packages.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Python-Packages.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Launch-Files.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Launch-Files.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Parameters.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Parameters.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Scripts.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Migrating-from-ROS1/Migrating-Scripts.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Launch-file-different-formats.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Launch-file-different-formats.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Launching-composable-nodes.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Launching-composable-nodes.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Node-arguments.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Node-arguments.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Sync-Vs-Async.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Sync-Vs-Async.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/DDS-tuning.html
# Failed to access https://docs.ros.org/en/How-To-Guides/DDS-tuning.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Overriding-QoS-Policies-For-Recording-And-Playback.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Overriding-QoS-Policies-For-Recording-And-Playback.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Working-with-multiple-RMW-implementations.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Working-with-multiple-RMW-implementations.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Cross-compilation.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Cross-compilation.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Releasing/Releasing-a-Package.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Releasing/Releasing-a-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Releasing/Index-Your-Packages.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Releasing/Index-Your-Packages.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Releasing/First-Time-Release.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Releasing/First-Time-Release.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Releasing/Subsequent-Releases.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Releasing/Subsequent-Releases.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Releasing/Release-Team-Repository.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Releasing/Release-Team-Repository.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Releasing/Release-Track.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Releasing/Release-Track.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Using-Python-Packages.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Using-Python-Packages.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Run-2-nodes-in-single-or-separate-docker-containers.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Run-2-nodes-in-single-or-separate-docker-containers.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Visualizing-ROS-2-Data-With-Foxglove-Studio.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Visualizing-ROS-2-Data-With-Foxglove-Studio.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Core-maintainer-guide.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Core-maintainer-guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Building-a-Custom-Deb-Package.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Building-a-Custom-Deb-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Building-ROS-2-with-Tracing-Instrumentation.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Building-ROS-2-with-Tracing-Instrumentation.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Topics-Services-Actions.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Topics-Services-Actions.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Using-Variants.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Using-Variants.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Using-ros2-param.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Using-ros2-param.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Using-ros1_bridge-Jammy-upstream.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Using-ros1_bridge-Jammy-upstream.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Configure-ZeroCopy-loaned-messages.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Configure-ZeroCopy-loaned-messages.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Installing-on-Raspberry-Pi.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Installing-on-Raspberry-Pi.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Using-callback-groups.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Using-callback-groups.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Getting-Backtraces-in-ROS-2.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Getting-Backtraces-in-ROS-2.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/ROS-2-IDEs.html
# Failed to access https://docs.ros.org/en/How-To-Guides/ROS-2-IDEs.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Setup-ROS-2-with-VSCode-and-Docker-Container.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Setup-ROS-2-with-VSCode-and-Docker-Container.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Using-Custom-Rosdistro.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Using-Custom-Rosdistro.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts.html
# Failed to access https://docs.ros.org/en/Concepts.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic.html
# Failed to access https://docs.ros.org/en/Concepts/Basic.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Nodes.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Nodes.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Discovery.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Discovery.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Interfaces.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Interfaces.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Topics.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Topics.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Services.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Services.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Actions.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Actions.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Parameters.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Parameters.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Command-Line-Tools.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Command-Line-Tools.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Launch.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Launch.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Basic/About-Client-Libraries.html
# Failed to access https://docs.ros.org/en/Concepts/Basic/About-Client-Libraries.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Domain-ID.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Domain-ID.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Different-Middleware-Vendors.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Different-Middleware-Vendors.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Logging.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Logging.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Quality-of-Service-Settings.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Quality-of-Service-Settings.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Executors.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Executors.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Topic-Statistics.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Topic-Statistics.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-RQt.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-RQt.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Composition.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Composition.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Cross-Compilation.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Cross-Compilation.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Security.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Security.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Intermediate/About-Tf2.html
# Failed to access https://docs.ros.org/en/Concepts/Intermediate/About-Tf2.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Advanced.html
# Failed to access https://docs.ros.org/en/Concepts/Advanced.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Advanced/About-Build-System.html
# Failed to access https://docs.ros.org/en/Concepts/Advanced/About-Build-System.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Advanced/About-Internal-Interfaces.html
# Failed to access https://docs.ros.org/en/Concepts/Advanced/About-Internal-Interfaces.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Advanced/About-Middleware-Implementations.html
# Failed to access https://docs.ros.org/en/Concepts/Advanced/About-Middleware-Implementations.html (Status code: 404)
# Found link: https://docs.ros.org/en/Contact.html
# Failed to access https://docs.ros.org/en/Contact.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Contributing.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing/Developer-Guide.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Contributing/Developer-Guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing/Code-Style-Language-Versions.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Contributing/Code-Style-Language-Versions.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing/Quality-Guide.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Contributing/Quality-Guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing/Build-Farms.html
# ...
# Found link: https://docs.ros.org/en/Guides/DDS-tuning.html
# Failed to access https://docs.ros.org/en/Guides/DDS-tuning.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Overriding-QoS-Policies-For-Recording-And-Playback.html
# Failed to access https://docs.ros.org/en/Guides/Overriding-QoS-Policies-For-Recording-And-Playback.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Working-with-multiple-RMW-implementations.html
# Failed to access https://docs.ros.org/en/Guides/Working-with-multiple-RMW-implementations.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Cross-compilation.html
# Failed to access https://docs.ros.org/en/Guides/Cross-compilation.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Releasing-a-ROS-2-package-with-bloom.html
# Failed to access https://docs.ros.org/en/Guides/Releasing-a-ROS-2-package-with-bloom.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Using-Python-Packages.html
# Failed to access https://docs.ros.org/en/Guides/Using-Python-Packages.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/RQt-Port-Plugin-Windows.html
# Failed to access https://docs.ros.org/en/Guides/RQt-Port-Plugin-Windows.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Run-2-nodes-in-single-or-separate-docker-containers.html
# Failed to access https://docs.ros.org/en/Guides/Run-2-nodes-in-single-or-separate-docker-containers.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Package-maintainer-guide.html
# Failed to access https://docs.ros.org/en/Guides/Package-maintainer-guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/Building-a-Custom-Debian-Package.html
# Failed to access https://docs.ros.org/en/Guides/Building-a-Custom-Debian-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/RQt-Source-Install.html
# Failed to access https://docs.ros.org/en/Guides/RQt-Source-Install.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/RQt-Source-Install-MacOS.html
# Failed to access https://docs.ros.org/en/Guides/RQt-Source-Install-MacOS.html (Status code: 404)
# Found link: https://docs.ros.org/en/Guides/RQt-Source-Install-Windows10.html
# Failed to access https://docs.ros.org/en/Guides/RQt-Source-Install-Windows10.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Domain-ID.html
# Failed to access https://docs.ros.org/en/Concepts/About-Domain-ID.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Command-Line-Tools.html
# Failed to access https://docs.ros.org/en/Concepts/About-Command-Line-Tools.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-RQt.html
# Failed to access https://docs.ros.org/en/Concepts/About-RQt.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Composition.html
# Failed to access https://docs.ros.org/en/Concepts/About-Composition.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Catment.html
# Failed to access https://docs.ros.org/en/Concepts/About-Catment.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Cross-Compilation.html
# Failed to access https://docs.ros.org/en/Concepts/About-Cross-Compilation.html (Status code: 404)
# Found link: https://docs.ros.org/en/dashing#ros-2-documentation
#
# Scraping https://docs.ros.org/en/dashing#ros-2-documentation (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_dashing.txt
#
# Following links:
# Found link: https://docs.ros.org/en/dashing#where-to-start
# Found link: https://docs.ros.org/en/Guides.html#guides
# Found link: https://docs.ros.org/en/dashing#about-ros-2
# Found link: https://docs.ros.org/en/dashing#about-this-documentation
# Found link: https://docs.ros.org/en/dashing#where-to-start
#
# Scraping https://docs.ros.org/en/dashing#where-to-start (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_dashing.txt
#
# Following links:
# Found link: https://docs.ros.org/en/Guides.html#guides
# Found link: https://docs.ros.org/en/dashing#about-ros-2
# Found link: https://docs.ros.org/en/dashing#about-this-documentation
# Found link: https://docs.ros.org/en/Guides.html#guides
# Failed to access https://docs.ros.org/en/Guides.html#guides (Status code: 404)
# Found link: https://docs.ros.org/en/dashing#about-ros-2
#
# Scraping https://docs.ros.org/en/dashing#about-ros-2 (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_dashing.txt
#
# Following links:
# Found link: https://docs.ros.org/en/dashing#about-this-documentation
# Found link: https://docs.ros.org/en/dashing#about-this-documentation
#
# Scraping https://docs.ros.org/en/dashing#about-this-documentation (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_dashing.txt
#
# Following links:
# Found link: https://docs.ros.org/en/eloquent
#
# Scraping https://docs.ros.org/en/eloquent (Depth: 2)
# Saved content to scraped_docs/docs.ros.org_en_eloquent.txt
#
# Following links:
# Found link: https://docs.ros.org/en/Tutorials/Getting-Started-With-Ros2doctor.html
# Failed to access https://docs.ros.org/en/Tutorials/Getting-Started-With-Ros2doctor.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/DDS-and-ROS-middleware-implementations.html
# Failed to access https://docs.ros.org/en/Concepts/DDS-and-ROS-middleware-implementations.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/ROS-2-Client-Libraries.html
# Failed to access https://docs.ros.org/en/Concepts/ROS-2-Client-Libraries.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/Logging.html
# Failed to access https://docs.ros.org/en/Concepts/Logging.html (Status code: 404)
# Found link: https://docs.ros.org/en/eloquent#ros-2-documentation
#
# Scraping https://docs.ros.org/en/eloquent#ros-2-documentation (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_eloquent.txt
#
# Following links:
# Found link: https://docs.ros.org/en/eloquent#where-to-start
# Found link: https://docs.ros.org/en/eloquent#learn-more
# Found link: https://docs.ros.org/en/eloquent#about-ros-2
# Found link: https://docs.ros.org/en/eloquent#about-this-documentation
# Found link: https://docs.ros.org/en/eloquent#where-to-start
#
# Scraping https://docs.ros.org/en/eloquent#where-to-start (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_eloquent.txt
#
# Following links:
# Found link: https://docs.ros.org/en/eloquent#learn-more
# Found link: https://docs.ros.org/en/eloquent#about-ros-2
# Found link: https://docs.ros.org/en/eloquent#about-this-documentation
# Found link: https://docs.ros.org/en/eloquent#learn-more
#
# Scraping https://docs.ros.org/en/eloquent#learn-more (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_eloquent.txt
#
# Following links:
# Found link: https://docs.ros.org/en/eloquent#about-ros-2
# Found link: https://docs.ros.org/en/eloquent#about-this-documentation
# Found link: https://docs.ros.org/en/eloquent#about-ros-2
#
# Scraping https://docs.ros.org/en/eloquent#about-ros-2 (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_eloquent.txt
#
# Following links:
# Found link: https://docs.ros.org/en/eloquent#about-this-documentation
# Found link: https://docs.ros.org/en/eloquent#about-this-documentation
#
# Scraping https://docs.ros.org/en/eloquent#about-this-documentation (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_eloquent.txt
#
# Following links:
# Found link: https://docs.ros.org/en/foxy
#
# Scraping https://docs.ros.org/en/foxy (Depth: 2)
# Saved content to scraped_docs/docs.ros.org_en_foxy.txt
#
# Following links:
# Found link: https://docs.ros.org/en/Installation/Alternatives/macOS-Install-Binary.html
# Failed to access https://docs.ros.org/en/Installation/Alternatives/macOS-Install-Binary.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Learning-About-Tf2-And-Time-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Learning-About-Tf2-And-Time-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Time-Travel-With-Tf2-Py.html
# Failed to access https://docs.ros.org/en/Tutorials/Intermediate/Tf2/Time-Travel-With-Tf2-Py.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Ignition/Simulation-Ignition.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Ignition/Simulation-Ignition.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Ignition/Ignition.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Ignition/Ignition.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Miscellaneous/Packaging-your-ROS-2-application-as-a-snap.html
# Failed to access https://docs.ros.org/en/Tutorials/Miscellaneous/Packaging-your-ROS-2-application-as-a-snap.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Launch-files-migration-guide.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Launch-files-migration-guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Parameters-YAML-files-migration-guide.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Parameters-YAML-files-migration-guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/RQt-Port-Plugin-Windows.html
# Failed to access https://docs.ros.org/en/How-To-Guides/RQt-Port-Plugin-Windows.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Package-maintainer-guide.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Package-maintainer-guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/Building-a-Custom-Debian-Package.html
# Failed to access https://docs.ros.org/en/How-To-Guides/Building-a-Custom-Debian-Package.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/RQt-Source-Install.html
# Failed to access https://docs.ros.org/en/How-To-Guides/RQt-Source-Install.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/RQt-Source-Install-MacOS.html
# Failed to access https://docs.ros.org/en/How-To-Guides/RQt-Source-Install-MacOS.html (Status code: 404)
# Found link: https://docs.ros.org/en/How-To-Guides/RQt-Source-Install-Windows10.html
# Failed to access https://docs.ros.org/en/How-To-Guides/RQt-Source-Install-Windows10.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Executors.html
# Failed to access https://docs.ros.org/en/Concepts/About-Executors.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Topic-Statistics.html
# Failed to access https://docs.ros.org/en/Concepts/About-Topic-Statistics.html (Status code: 404)
# Found link: https://docs.ros.org/en/Concepts/About-Tf2.html
# Failed to access https://docs.ros.org/en/Concepts/About-Tf2.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing/Migration-Guide.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Contributing/Migration-Guide.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Contributing/Migration-Guide-Python.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Contributing/Migration-Guide-Python.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Governance/ROS2-TSC-Charter.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Governance/ROS2-TSC-Charter.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Governance/ROS2-TSC-Intake-process.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Governance/ROS2-TSC-Intake-process.html (Status code: 404)
# Found link: https://docs.ros.org/en/The-ROS2-Project/Governance/How-To-Start-A-Community-Working-Group.html
# Failed to access https://docs.ros.org/en/The-ROS2-Project/Governance/How-To-Start-A-Community-Working-Group.html (Status code: 404)
# Found link: https://docs.ros.org/en/foxy#ros-2-documentation
#
# Scraping https://docs.ros.org/en/foxy#ros-2-documentation (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_foxy.txt
#
# Following links:
# Found link: https://docs.ros.org/en/foxy#getting-started
# Found link: https://docs.ros.org/en/foxy#the-ros-2-project
# Found link: https://docs.ros.org/en/foxy#other-ros-resources
# Found link: https://docs.ros.org/en/Contact.html#using-ros-answers
# Found link: https://docs.ros.org/en/foxy#deprecated
# Found link: https://docs.ros.org/en/foxy#getting-started
#
# Scraping https://docs.ros.org/en/foxy#getting-started (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_foxy.txt
#
# Following links:
# Found link: https://docs.ros.org/en/foxy#the-ros-2-project
# Found link: https://docs.ros.org/en/foxy#other-ros-resources
# Found link: https://docs.ros.org/en/Contact.html#using-ros-answers
# Found link: https://docs.ros.org/en/foxy#deprecated
# Found link: https://docs.ros.org/en/foxy#the-ros-2-project
#
# Scraping https://docs.ros.org/en/foxy#the-ros-2-project (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_foxy.txt
#
# Following links:
# Found link: https://docs.ros.org/en/foxy#other-ros-resources
# Found link: https://docs.ros.org/en/Contact.html#using-ros-answers
# Found link: https://docs.ros.org/en/foxy#deprecated
# Found link: https://docs.ros.org/en/foxy#other-ros-resources
#
# Scraping https://docs.ros.org/en/foxy#other-ros-resources (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_foxy.txt
#
# Following links:
# Found link: https://docs.ros.org/en/Contact.html#using-ros-answers
# Found link: https://docs.ros.org/en/foxy#deprecated
# Found link: https://docs.ros.org/en/Contact.html#using-ros-answers
# Failed to access https://docs.ros.org/en/Contact.html#using-ros-answers (Status code: 404)
# Found link: https://docs.ros.org/en/foxy#deprecated
#
# Scraping https://docs.ros.org/en/foxy#deprecated (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_foxy.txt
#
# Following links:
# Found link: https://docs.ros.org/en/galactic
#
# Scraping https://docs.ros.org/en/galactic (Depth: 2)
# Saved content to scraped_docs/docs.ros.org_en_galactic.txt
#
# Following links:
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Webots.html (Status code: 404)
# Found link: https://docs.ros.org/en/Tutorials/Advanced/Simulators/Ignition.html
# Failed to access https://docs.ros.org/en/Tutorials/Advanced/Simulators/Ignition.html (Status code: 404)
# Found link: https://docs.ros.org/en/galactic#ros-2-documentation
#
# Scraping https://docs.ros.org/en/galactic#ros-2-documentation (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_galactic.txt
#
# Following links:
# Found link: https://docs.ros.org/en/galactic#getting-started
# Found link: https://docs.ros.org/en/galactic#the-ros-2-project
# Found link: https://docs.ros.org/en/galactic#other-ros-resources
# Found link: https://docs.ros.org/en/galactic#deprecated
# Found link: https://docs.ros.org/en/galactic#getting-started
#
# Scraping https://docs.ros.org/en/galactic#getting-started (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_galactic.txt
#
# Following links:
# Found link: https://docs.ros.org/en/galactic#the-ros-2-project
# Found link: https://docs.ros.org/en/galactic#other-ros-resources
# Found link: https://docs.ros.org/en/galactic#deprecated
# Found link: https://docs.ros.org/en/galactic#the-ros-2-project
#
# Scraping https://docs.ros.org/en/galactic#the-ros-2-project (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_galactic.txt
#
# Following links:
# Found link: https://docs.ros.org/en/galactic#other-ros-resources
# Found link: https://docs.ros.org/en/galactic#deprecated
# Found link: https://docs.ros.org/en/galactic#other-ros-resources
#
# Scraping https://docs.ros.org/en/galactic#other-ros-resources (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_galactic.txt
#
# Following links:
# Found link: https://docs.ros.org/en/galactic#deprecated
# Found link: https://docs.ros.org/en/galactic#deprecated
#
# Scraping https://docs.ros.org/en/galactic#deprecated (Depth: 3)
# Saved content to scraped_docs/docs.ros.org_en_galactic.txt
#
# Following links:
